# %% [markdown]
# # Familiarize with the Experimental Setup
#
# First, let's familiarize ourselves with the operating environment for the experiment. The experimental operating environment for the course uses Baidu's PaddlePaddle AI Studio platform. PaddlePaddle AI Studio is an integrated development environment launched by Baidu that provides rich AI development tools and resources, suitable for experiments and project development in machine learning and deep learning.
#
# You can access the PaddlePaddle AI Studio platform through the following link:
# https://aistudio.baidu.com/aistudio/education/group/invitation/35983?code=BAoNT2
#
# Clicking this link will redirect you to the login page for our course on PaddlePaddle AI Studio. After correctly entering **your name** and **student ID**, you can enter the learning session of the course. You can find the experimental materials corresponding to this course in the assignment area.

# %% [markdown]
# ## Basic Image Operations
#
# In our upcoming lab sessions, the two core Python libraries we will rely on for machine vision tasks are OpenCV and scikit-image (skimage). As a quick warm-up, let's try loading and displaying a standard test image directly from the skimage library.
#
# We encourage the use of AI-assisted programming (vibe coding) in this course. If you are using DeepSeek Chat as your primary language model, you can use the following prompt to generate the required code:
#
# **Please write a Python script to load and display a standard test image from the skimage library. To prevent any character encoding issues in the output, please ensure that all code and comments are written entirely in English.**

# %%
# Add your code here

# %% [markdown]
# Next, we can perform some basic geometric transformations on the image, such as rotating it by 45 degrees. You can continue using the language model to generate the necessary code by using the following prompt:
#
# **Please write a Python script to load and rotate a standard image from the skimage library 45 degrees clockwise around the origin of the coordinate system, and display the result. To prevent any character encoding issues, please ensure that all code and comments are written entirely in English.**

# %%
# Add your code here

# %% [markdown]
# Next, let's try performing a translation operation on the image, shifting it by 20 pixels along the X-axis (horizontally) and 50 pixels along the Y-axis (vertically). You can use the following prompt to generate the corresponding code:
#
# **Please write a Python script to load a standard test image from the skimage library, translate (shift) the image by 20 pixels along the X-axis and 50 pixels along the Y-axis, and display the result. To prevent any character encoding issues, please ensure that all code and comments are written entirely in English.**

# %%
# Add your code here

# %% [markdown]
# Now we reduce the image to half its original size. The following prompt can be used:
#
# **Please write Python code to load an image from the skimage library and then reduce the loaded image to half its size and display it. To avoid any character encoding issues, all code and comments should be written in English.**

# %%
# Add your code here

# %% [markdown]
# ## Conclusion
#
# What you have learned in this practice session, please write down your summary in the following cell.

# %% [markdown]
# # Add your summary here
